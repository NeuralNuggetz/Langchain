# %%
import random
class NakliLLM:
    def __init__(self):
        print('LLM created')

    def predict(self, prompt):
        response_list = [
            'Delhi is the capital of India',
            'IPL is a cricket league',
            'AI stands for Artifical Intelligence'
        ]

        return {'response':random.choice(response_list)}

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict('WHat is the capital of India')
# Out:
# {'response': 'AI stands for Artifical Intelligence'}

# %% [markdown]
# ## Second Class

# %%
class NakliPromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template = 'Write a poem about {topic}',
    input_variables=['topic']
)

# %%
prompt = template.format({'topic':'India'})

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'AI stands for Artifical Intelligence'}

# %%
class NakliLLMCHain:
    def __init__(self, llm, prompt):
        self.llm = llm
        self.prompt = prompt

    def run(self, input_dict):
        finalprompt = self.prompt.format(input_dict)
        result = self.llm.predict(finalprompt)

        return result['response']

# %%
template = NakliPromptTemplate(
    template = 'Write a poem about {topic}',
    input_variables=['topic']
)

# %%
llm = NakliLLM()
# Out:
# LLM created

# %%
chain = NakliLLMCHain(
    llm, template
)

# %%
chain.run({'topic':'India'})
# Out:
# 'Delhi is the capital of India'
